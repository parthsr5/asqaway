# %%
# %cd drive/MyDrive/11797
# Out:
# /content/drive/MyDrive/11797

# %%
# !ls
# Out:
# 'Adversarial Finetuning Eval.ipynb'   bioelectra_base_9b
#  adversarial-squad3		      Ensembling.ipynb
#  bioalbert_base_11b		     'Model Finetuning Eval.ipynb'
#  bioalbert_base_11b_v2		     'Model Testing.ipynb'
#  bioalbert_base_11b_v2_test	      postprocess_results
#  biobert_base_11b		      preprocessed-training11b.json
#  biobert_base_11b_v2		      Presentations
#  biobert_base_11b_v2_test	      run_qa.py
#  biobert_base_9b		      Submissions.gsheet
#  bioelectra_base_11b		      test
#  bioelectra_base_11b_v2		      train_file.json
#  bioelectra_base_11b_v2_test	      training11b.json

# %%
# %cd adversarial-squad3
# Out:
# /content/drive/MyDrive/11797/adversarial-squad3

# %%
# !pip install -r requirements.txt
import nltk
nltk.download('punkt')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 64.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.1/88.1 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 97.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 88.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.4/348.4 kB 32.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.6/100.6 kB 11.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !python src/py/find_squad_nearby_words.py glove/glove.6B.100d.txt -n 100 -f data/train_file_80_11b_squad.json
# Out:
# Found 3822 words
# 400000it [00:12, 32033.41it/s]
# Found vectors for 2780/3822 words = 72.74%
# 100% 2780/2780 [05:56<00:00,  7.81it/s]

# %%
# %cd /content/drive/MyDrive/11797/adversarial-squad3/
# Out:
# /content/drive/MyDrive/11797/adversarial-squad3

# %%
# !ls
# Out:
# bi-att-flow-dev  launch     mturk   pull-dependencies.sh  src
# data		 LICENSE    nectar  README.md
# glove		 matchlstm  out     requirements.txt

# %%
# !python src/py/convert_questions.py corenlp -d train
# Out:
# Using lib directory /content/drive/MyDrive/11797/adversarial-squad3/src/py/lib/stanford-corenlp/*
#
# ^C

# %%
# !python run_qa.py \
    --model_name_or_path dmis-lab/biobert-base-cased-v1.1-squad \
    --tokenizer_name dmis-lab/biobert-base-cased-v1.1-squad \
    --do_train=True \
    --train_file train_file_80_11b.json \
    --do_eval=True \
    --validation_file test_file_80_11b.json \
    --do_predict=True \
    --test_file test_file_80_11b.json \
    --num_train_epochs 5 \
    --save_strategy epoch \
    --evaluation_strategy epoch \
    --metric_for_best_model eval_f1 \
    --load_best_model_at_end \
    --output_dir /content/biobert_11b \
    --overwrite_output_dir
# Out:
# 2023-03-14 00:21:06.092993: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-14 00:21:07.314111: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-14 00:21:07.314269: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
# !python run_qa.py \
    --model_name_or_path sultan/BioM-ELECTRA-Base-SQuAD2 \
    --tokenizer_name sultan/BioM-ELECTRA-Base-SQuAD2 \
    --do_train=True \
    --train_file train_file_80_11b.json \
    --do_eval=True \
    --validation_file test_file_80_11b.json \
    --do_predict=True \
    --test_file test_file_80_11b.json \
    --num_train_epochs 5 \
    --save_strategy epoch \
    --evaluation_strategy epoch \
    --metric_for_best_model eval_f1 \
    --load_best_model_at_end \
    --output_dir /content/bioelectra_base_11b \
    --overwrite_output_dir
# Out:
# 2023-03-14 02:09:18.645112: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-14 02:09:20.578512: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-14 02:09:20.578689: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
# !python run_qa.py \
    --model_name_or_path sultan/BioM-ALBERT-xxlarge-SQuAD2 \
    --tokenizer_name sultan/BioM-ALBERT-xxlarge-SQuAD2 \
    --do_train=True \
    --train_file train_file_80_11b.json \
    --per_device_train_batch_size 4 \
    --do_eval=True \
    --validation_file test_file_80_11b.json \
    --do_predict=True \
    --test_file test_file_80_11b.json \
    --num_train_epochs 1 \
    --save_strategy epoch \
    --evaluation_strategy epoch \
    --metric_for_best_model eval_f1 \
    --load_best_model_at_end \
    --output_dir /content/bioalbert_base_11b \
    --fp16 \
    --overwrite_output_dir
# Out:
# 2023-03-22 02:57:16.584185: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-22 02:57:17.497163: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-22 02:57:17.497260: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
# %cd /content
# !ls
# !mv biobert_base_11b/ drive/MyDrive/11797
# !mv bioelectra_base_11b/ drive/MyDrive/11797
# !mv bioalbert_base_11b/ drive/MyDrive/11797
# Out:
# /content
# bioalbert_base_11b  bioelectra_base_11b  drive	sample_data  transformers
